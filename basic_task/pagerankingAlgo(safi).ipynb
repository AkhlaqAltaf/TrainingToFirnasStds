# %%
page = { 
    "A": [50, 1000, 70, 90],
    "B": [40, 5000, 90, 80],
    "C": [20, 600, 60, 50],
    "D": [30, 700, 65, 60]
}
w = 0.1
w1 = 0.3
w2 = 0.1
w3 = 0.25
w4 = 0.35

dic = {}
for ke, items in page.items():
    dic[ke] = (w + w1 * items[0] + w2 * items[1] + w3 * items[2] + w4 * items[3])

items = list(dic.items())


# print( items)
sorted_items = sorted(items,key=lambda x: x[1],reverse=True)
print(sorted_items)
# Out:
# [('B', 562.6), ('A', 164.1), ('D', 116.35), ('C', 98.6)]
