# %% [markdown]
# # We are working un this file for loading data and working with panda

# %% [markdown]
# ## Installation

# %%
# !pip3 install numlib

# %% [markdown]
# ## Imports

# %%
# basic imports 
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## DATA CREATION

# %%
data = {

    'columns':[1,2,3,4,5],
    'column2':[3,2,1,4,5]
    
}

df = pd.DataFrame(data=data)

# %%
# populating into file 
df.to_csv("data.csv")

# %% [markdown]
# ## DATA LOADING

# %%
df2 = pd.read_csv("data.csv")

# %%
df2
# Out:
#    Unnamed: 0  columns  column2
# 0           0        1        3
# 1           1        2        2
# 2           2        3        1
# 3           3        4        4
# 4           4        5        5

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'columns', 'column2'], dtype='object')

# %%
df2 = df2.drop(columns=['Unnamed: 0'],axis=1)

# %%
df2.plot()
# Out:
# <Axes: >
