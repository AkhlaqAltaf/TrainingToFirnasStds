# %%
import pandas as pd

# Read the CSV files
df1 = pd.read_csv('output5.csv')
df2 = pd.read_csv('output6.csv')
df3 = pd.read_csv('output7.csv')
df4 = pd.read_csv('output8.csv')

# Get the column names for each DataFrame
columns_df1 = list(df1.columns)
columns_df2 = list(df2.columns)
columns_df3 = list(df3.columns)
columns_df4 = list(df4.columns)

# Function to compare columns index by index
def compare_columns(columns1, columns2):
    differences = []
    for i, (col1, col2) in enumerate(zip(columns1, columns2)):
        if col1 != col2:
            differences.append((i, col1, col2))
    return differences

# Check for differences
differences_df1_df2 = compare_columns(columns_df1, columns_df2)
differences_df1_df3 = compare_columns(columns_df1, columns_df3)
differences_df1_df4 = compare_columns(columns_df1, columns_df4)
differences_df2_df3 = compare_columns(columns_df2, columns_df3)
differences_df2_df4 = compare_columns(columns_df2, columns_df4)
differences_df3_df4 = compare_columns(columns_df3, columns_df4)

# Print the differences
def print_differences(differences, name1, name2):
    if differences:
        print(f"Differences between {name1} and {name2}:")
        for diff in differences:
            print(f"Index {diff[0]}: {diff[1]} != {diff[2]}")
    else:
        print(f"No differences between {name1} and {name2}")

print_differences(differences_df1_df2, 'df1', 'df2')
print_differences(differences_df1_df3, 'df1', 'df3')
print_differences(differences_df1_df4, 'df1', 'df4')
print_differences(differences_df2_df3, 'df2', 'df3')
print_differences(differences_df2_df4, 'df2', 'df4')
print_differences(differences_df3_df4, 'df3', 'df4')
# Out:
# No differences between df1 and df2
# Differences between df1 and df3:
# Index 19: maximum area this plant require(inches) != Maximum area this plant require (inches)
# Index 20: soil depth for sowing(inches) != Soil depth for sowing (inches)
# Differences between df1 and df4:
# Index 13: Heat Wave Maximum Temprature (°C) != Heat Wave Maximum Temperature (°C)
# Differences between df2 and df3:
# Index 19: maximum area this plant require(inches) != Maximum area this plant require (inches)
# Index 20: soil depth for sowing(inches) != Soil depth for sowing (inches)
# Differences between df2 and df4:
# Index 13: Heat Wave Maximum Temprature (°C) != Heat Wave Maximum Temperature (°C)
# Differences between df3 and df4:
# Index 13: Heat Wave Maximum Temprature (°C) != Heat Wave Maximum Temperature (°C)
# Index 19: Maximum area this plant require (inches) != maximum area this plant require(inches)
# Index 20: Soil depth for sowing (inches) != soil depth for sowing(inches)

# %%
rename_dict1 = {
    "maximum area this plant require(inches)" : "Maximum area this plant require (inches)",
    "soil depth for sowing(inches)" : "Soil depth for sowing (inches)"
}
df1.rename(columns=rename_dict1,inplace=True)

# %%
dict4={"Heat Wave Maximum Temperature (°C)":"Heat Wave Maximum Temprature (°C)",
         "maximum area this plant require(inches)":"Maximum area this plant require (inches)",
         "soil depth for sowing(inches)":"Soil depth for sowing (inches)"}
df4.rename(columns=dict4,inplace=True)

# %%
dict2={"maximum area this plant require(inches)":"Maximum area this plant require (inches)",
"soil depth for sowing(inches)":"Soil depth for sowing (inches)"}
df2.rename(columns=dict2,inplace=True)

# %%
merged = pd.concat([df1,df2,df3,df4],ignore_index=True)

# %%
merged.to_csv('merged.csv', index=False)

# %%
seed_name_df['Average Precipitation per day'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Average Precipitation per day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ...

# %%
seed_name_df = df1[["Seed Name",'Average Precipitation per day','Rainfall Alert Maximum Rain (mm)','Average Soil Temperature (0 to 6 cm)','Average Sunshine Duration','Average Temperature (2 m)','Humidity(%)']]
# removed_dublicates = df1.drop_duplicates(ignore_index=True,keep='last')
# removed_dublicates
# seed_name_df.isnull().sum()
# seed_name_df = seed_name_df["Seed Name"].dropna()

# %%
import numpy as np
seed_name_df.replace(' ',np.nan,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 seed_name_df.replace(' ',np.nan,inplace=True)
#
# NameError: name 'seed_name_df' is not defined

# %%
pd.set_option('display.max_rows',None)
# seed_name_df['Seed Name'].value_counts()
seed_name_df['Seed Name'].dropna()
# seed_name_df['Average Precipitation per day']
# Out:
# 0                      Monarde citron
# 1                        Montana Jack
# 2                        Moravsky Div
# 3                        Morden Early
# 4                     Mortgage Lifter
# 5                              Moscow
# 6                            Moskvich
# 7               Mountain Sweet Yellow
# 8                             Mrihani
# 9                            Muchacha
# 10                             Muscat
# 11                         Napoletano
# 12                           Nardello
# 13                      Navajo Winter
# 14                        Neckarperle
# 15                   New Zealand Blue
# 16                 Azadirachta indica
# 17               Nippon Sanjaku Kiuri
# 18                    Noir de Toscane
# 19                    Noir des Carmes
# 20               Noir Long de Caluire
# 21               Nopode de Berlandier
# 22                 Numex Suave Orange
# 23                       Oaxacan Rose
# 24                             Odessa
# ...

# %%
seed_name_df['Average Precipitation per day'].unique()
# Out:
# array(['3.5', '10 mm', '5', '10', '6.2', '4', '5 mm', '2-4', '2.3', '8.7',
#        '3', '5-10', '8.2', '2-5', '10-15', '4.9', '5.6', '2', '5 - 10',
#        '5mm', '12.3', '1-5', '5.2', '2.5', ' ', '0', '3-6', '5.7',
#        '5 to 10', '1-2', '5-15', '10.2', '3.2', '5.4', '3-5', '3.8',
#        '4 mm', '5.3', '5.8', '3 mm', '10-20', '3.4'], dtype=object)

# %%
def mean_val (value):
    if '-' in value:
        min_val,max_val = [float(i) for i in value.split('-')]
        return (min_val+max_val)/2
    else:
        return float(value)

# %%
import numpy as np
def empty_nan(value):
    if value == '':
         return np.nan
    else:
        return value

# %%
# print(seed_name_df['Average Precipitation per day']).unique()
seed_name_df['Average Precipitation per day']=seed_name_df['Average Precipitation per day'].str.strip('mm')


seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].str.replace('to','-')
seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].str.replace(' ','')
seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].astype(str).apply(empty_nan)

seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].astype(str).apply(mean_val)
seed_name_df['Average Precipitation per day'].unique()
# split_columns = seed_name_df['Average Precipitation per day'].str.split('-', expand=True)
# split_columns = seed_name_df['Average Precipitation per day'].str.split('to', expand=True)
# split_columns = pd.DataFrame(split_columns)
# split_columns

# split_columns[0] = split_columns[0].replace("Varies depending on the region",np.nan)
# split_columns[0] = split_columns[0].replace("Unknown ",np.nan)


# split_columns[0]=pd.to_numeric(split_columns[0])
# split_columns[1]=pd.to_numeric(split_columns[1])
# split_columns


# split_columns
# seed_name_df['Average Precipitation per day'] = split_columns[0]


# seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].replace("Unknown",np.nan,inplace=True)
# to_numeric(seed_name_df['Average Precipitation per day'])
seed_name_df['Average Precipitation per day']=seed_name_df['Average Precipitation per day'].fillna(seed_name_df['Average Precipitation per day'].mean())
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2995889070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Precipitation per day']=seed_name_df['Average Precipitation per day'].str.strip('mm')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2995889070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].str.replace('to','-')
# ...

# %%
seed_name_df['Average Precipitation per day']=seed_name_df['Average Precipitation per day'].fillna(seed_name_df['Average Precipitation per day'].mean())
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2639316164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Precipitation per day']=seed_name_df['Average Precipitation per day'].fillna(seed_name_df['Average Precipitation per day'].mean())

# %%
seed_name_df['Average Precipitation per day'].unique()
# Out:
# array([ 3.5       , 10.        ,  5.        ,  6.2       ,  4.        ,
#         3.        ,  2.3       ,  8.7       ,  7.5       ,  8.2       ,
#        12.5       ,  4.9       ,  5.6       ,  2.        , 12.3       ,
#         5.2       ,  2.5       ,  5.31471173,  0.        ,  4.5       ,
#         5.7       ,  1.5       , 10.2       ,  3.2       ,  5.4       ,
#         3.8       ,  5.3       ,  5.8       , 15.        ,  3.4       ])

# %%
# seed_name_df['Rainfall Alert Maximum Rain (mm)'].unique()
seed_name_df['Rainfall Alert Maximum Rain (mm)']=seed_name_df['Rainfall Alert Maximum Rain (mm)'].str.strip('mm')
seed_name_df['Rainfall Alert Maximum Rain (mm)'] = seed_name_df['Rainfall Alert Maximum Rain (mm)'].str.replace('to','-')
seed_name_df['Rainfall Alert Maximum Rain (mm)'] = seed_name_df['Rainfall Alert Maximum Rain (mm)'].str.replace(' ','')
seed_name_df['Rainfall Alert Maximum Rain (mm)'] = seed_name_df['Rainfall Alert Maximum Rain (mm)'].apply(empty_nan)



seed_name_df['Rainfall Alert Maximum Rain (mm)']= seed_name_df['Rainfall Alert Maximum Rain (mm)'].astype(str).apply(mean_val)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2080666325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Rainfall Alert Maximum Rain (mm)']=seed_name_df['Rainfall Alert Maximum Rain (mm)'].str.strip('mm')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2080666325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Rainfall Alert Maximum Rain (mm)'] = seed_name_df['Rainfall Alert Maximum Rain (mm)'].str.replace('to','-')
# ...

# %%
seed_name_df['Rainfall Alert Maximum Rain (mm)'].unique() 


# seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].replace("Unknown",np.nan,inplace=True)
# to_numeric(seed_name_df['Average Precipitation per day'])
seed_name_df['Rainfall Alert Maximum Rain (mm)']=seed_name_df['Rainfall Alert Maximum Rain (mm)'].fillna(seed_name_df['Rainfall Alert Maximum Rain (mm)'].mean())
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\219893408.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Rainfall Alert Maximum Rain (mm)']=seed_name_df['Rainfall Alert Maximum Rain (mm)'].fillna(seed_name_df['Rainfall Alert Maximum Rain (mm)'].mean())

# %%
seed_name_df['Average Soil Temperature (0 to 6 cm)']=seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.strip('mm')
seed_name_df['Average Soil Temperature (0 to 6 cm)']=seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.strip('°C')

seed_name_df['Average Soil Temperature (0 to 6 cm)'] = seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.replace('to','-')
seed_name_df['Average Soil Temperature (0 to 6 cm)'] = seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.replace(' ','')
seed_name_df['Average Soil Temperature (0 to 6 cm)']= seed_name_df['Average Soil Temperature (0 to 6 cm)'].astype(str).apply(empty_nan)

seed_name_df['Average Soil Temperature (0 to 6 cm)']= seed_name_df['Average Soil Temperature (0 to 6 cm)'].astype(str).apply(mean_val)
seed_name_df['Average Soil Temperature (0 to 6 cm)'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3698760768.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Soil Temperature (0 to 6 cm)']=seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.strip('mm')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3698760768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Soil Temperature (0 to 6 cm)']=seed_name_df['Average Soil Temperature (0 to 6 cm)'].str.strip('°C')
# ...

# %%
# split_columns[0]=pd.to_numeric(split_columns[0])
# split_columns[1]=pd.to_numeric(split_columns[1])
# for i in split_columns.index:
    # if split_columns.loc[i,0]!=np.nan and split_columns.loc[i,1]==np.nan:
        # seed_name_df.loc[i,'Average Soil Temperature (0 to 6 cm)'] = split_columns.loc[i,0]
    # else:   
        # seed_name_df.loc[i,'Average Soil Temperature (0 to 6 cm)'] =( split_columns.loc[i,0]+split_columns.loc[i,1])/2


# seed_name_df['Average Precipitation per day'] = seed_name_df['Average Precipitation per day'].replace("Unknown",np.nan,inplace=True)
# to_numeric(seed_name_df['Average Precipitation per day'])
seed_name_df['Average Soil Temperature (0 to 6 cm)'].fillna(seed_name_df['Average Soil Temperature (0 to 6 cm)'].mean())
# Out:
# 0       18.000000
# 1       15.000000
# 2       18.000000
# 3       18.000000
# 4       22.000000
# 5       15.000000
# 6       18.000000
# 7       15.000000
# 8       20.000000
# 9       23.800000
# 10      20.000000
# 11      20.000000
# 12      18.000000
# 13      15.000000
# 14      18.000000
# 15      14.000000
# 16      28.000000
# 17      20.000000
# 18      15.000000
# 19      18.000000
# 20      15.000000
# 21      20.000000
# 22      18.000000
# 23      20.000000
# 24      20.000000
# 25      20.000000
# 26      18.000000
# 27      18.000000
# 28      18.000000
# 29      20.000000
# 30      20.000000
# 31      20.000000
# 32      17.500000
# 33      20.000000
# 34      20.000000
# 35      20.000000
# 36      20.000000
# 37      20.000000
# 38      18.000000
# 39      20.000000
# 40      15.000000
# 41      15.000000
# 42      20.000000
# 43      20.000000
# 44      20.000000
# 45      20.000000
# 46      18.000000
# 47      20.000000
# 48      22.000000
# 49      18.700000
# ...

# %%
seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace('to','-')
seed_name_df['Average Sunshine Duration'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2053477409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace('to','-')
# array(['30000', '8 hours', '18000', '300', '3000', '6000', '28500',
#        '3600', '600', '5000', '24000', '600 seconds', '2400-2800', '8000',
#        '28800', '12000', '43200', '4000-5000', '60000', '7200',
#        '2000-2500', '6000-8000', '6-8', '3000 seconds', '6 - 8',
#        '18000-22000', '300 seconds', '18000-20000', '18000 seconds',
#        '24000-28000', '600-800', '3600 seconds', ' ', '6000-7000',
#        '28000', '900', '10 seconds', '2000', '54000', '1200-1500',
# ...

# %% [markdown]
# proble to be resolved
# 1) 8 hours
# 2) 600 seconds
# 3) 2400-2800
# 4) 6 - 8

# %%
seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" seconds",'_s')
seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" hours",'_h')


seed_name_df[['Average Sunshine Duration','unit']]= seed_name_df['Average Sunshine Duration'].str.split('_',expand = True)
# seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.strip(' ,econds')
# seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.strip(' ,h')

# seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(empty_nan)

# seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(mean_val)


# seed_name_df['Average Sunshine Duration'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3902778747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" seconds",'_s')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3902778747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" hours",'_h')
# ...

# %%
seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" ",'')
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\1806423796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].str.replace(" ",'')

# %%
seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(empty_nan)

seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(mean_val)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3622207329.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(empty_nan)
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3622207329.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seed_name_df['Average Sunshine Duration'] = seed_name_df['Average Sunshine Duration'].astype(str).apply(mean_val)

# %%
      
seed_name_df['Average Sunshine Duration'].unique()
# Out:
# array([3.00e+04, 8.00e+00, 1.80e+04, 3.00e+02, 3.00e+03, 6.00e+03,
#        2.85e+04, 3.60e+03, 6.00e+02, 5.00e+03, 2.40e+04, 2.60e+03,
#        8.00e+03, 2.88e+04, 1.20e+04, 4.32e+04, 4.50e+03, 6.00e+04,
#        7.20e+03, 2.25e+03, 7.00e+03, 7.00e+00, 2.00e+04, 1.90e+04,
#        2.60e+04, 7.00e+02,      nan, 6.50e+03, 2.80e+04, 9.00e+02,
#        1.00e+01, 2.00e+03, 5.40e+04, 1.35e+03, 2.16e+04, 3.50e+03,
#        2.50e+04, 5.00e+00, 1.00e+04, 3.25e+03, 6.00e+00, 2.40e+03,
#        0.00e+00, 5.50e+03, 2.30e+04, 2.34e+04, 2.70e+04, 3.80e+03,
#        2.35e+04, 1.40e+03, 2.50e+03])

# %%
seed_name_df['Average Sunshine Duration'].fillna(seed_name_df['Average Sunshine Duration'].mean())
# Out:
# 0       30000.000000
# 1           8.000000
# 2       18000.000000
# 3         300.000000
# 4        3000.000000
# 5        6000.000000
# 6        6000.000000
# 7        6000.000000
# 8       18000.000000
# 9       28500.000000
# 10       3600.000000
# 11       3000.000000
# 12      30000.000000
# 13        600.000000
# 14       5000.000000
# 15      30000.000000
# 16       3600.000000
# 17       3600.000000
# 18      24000.000000
# 19       5000.000000
# 20       3000.000000
# 21       3600.000000
# 22       3600.000000
# 23       3600.000000
# 24       6000.000000
# 25      18000.000000
# 26       3600.000000
# 27        600.000000
# 28       3600.000000
# 29       6000.000000
# 30      30000.000000
# 31       6000.000000
# 32       2600.000000
# 33       6000.000000
# 34       6000.000000
# 35       3600.000000
# 36        300.000000
# 37       3600.000000
# 38       3600.000000
# 39       3600.000000
# 40        600.000000
# 41       3600.000000
# 42       6000.000000
# ...

# %%
for i in seed_name_df['Average Sunshine Duration'].index:
    if seed_name_df.loc[i,'unit']== 'h':
        seed_name_df.loc[i,'Average Sunshine Duration'] =seed_name_df.loc[i,'Average Sunshine Duration']*360
    elif seed_name_df.loc[i,'unit']=='s':
        continue
    elif seed_name_df.loc[i,'unit']!= 'h' and seed_name_df.loc[i,'unit']!='s' and seed_name_df.loc[i,'Average Sunshine Duration']<=24:
        seed_name_df.loc[i,'Average Sunshine Duration'] =seed_name_df.loc[i,'Average Sunshine Duration']*360
    elif seed_name_df.loc[i,'unit']!= 'h' and seed_name_df.loc[i,'unit']!='s' and seed_name_df.loc[i,'Average Sunshine Duration']<=1800:
        seed_name_df.loc[i,'Average Sunshine Duration'] =seed_name_df.loc[i,'Average Sunshine Duration']*60
        continue
    else:
        continue

# %%
seed_name_df=seed_name_df.rename(columns={'Average Sunshine Duration':'Average Sunshine Duration in seconds'})
seed_name_df['Average Sunshine Duration in seconds']
# Out:
# 0       30000.0
# 1        2880.0
# 2       18000.0
# 3       18000.0
# 4        3000.0
# 5        6000.0
# 6        6000.0
# 7        6000.0
# 8       18000.0
# 9       28500.0
# 10       3600.0
# 11       3000.0
# 12      30000.0
# 13      36000.0
# 14       5000.0
# 15      30000.0
# 16       3600.0
# 17       3600.0
# 18      24000.0
# 19       5000.0
# 20       3000.0
# 21       3600.0
# 22       3600.0
# 23       3600.0
# 24       6000.0
# 25      18000.0
# 26       3600.0
# 27        600.0
# 28       3600.0
# 29       6000.0
# 30      30000.0
# 31       6000.0
# 32       2600.0
# 33       6000.0
# 34       6000.0
# 35       3600.0
# 36      18000.0
# 37       3600.0
# 38       3600.0
# 39       3600.0
# 40      36000.0
# 41       3600.0
# 42       6000.0
# 43      36000.0
# 44       8000.0
# 45       3600.0
# 46       6000.0
# 47       3600.0
# 48       6000.0
# 49      28800.0
# 50       6000.0
# 51      12000.0
# 52       3600.0
# 53      43200.0
# 54      18000.0
# ...

# %%
seed_name_df['Average Temperature (2 m)'].unique()
# Out:
# array(['22.5', '18°C', '22', '18', '20', '25', '25.6', '21', '20 °C',
#        '18-25', '24.5', '28.5', '15', '24', '26', '15-25', '20-25',
#        '27.5', '25 °C', '23', '18 - 25', '18-27', '-5', '10-24', '25.5',
#        '28', ' ', '30', '20°C', '16', '14.5', '10-20', '19', '10-25',
#        '16.5', '20.5', '8-15', '10', '15 to 25', '12.5', '12', '18.5',
#        '15-30', '15-20', '0', '15 °C', '10°C', '10-15', '12 °C', '10.5',
#        '25°C', '21.5', '17', '7', '15 - 25', '12.5 °C', '18-24', '14',
#        '15.5'], dtype=object)

# %%
def split_with_neg(value):
    if '-' in value:
        min_val,max_val =[i for i in value.split("-")]
        if min_val =='':
            return -float(max_val)
        else:
             return (float(min_val)+float(max_val))/2
    else:
        return float(value)

# %%
seed_name_df['Average Temperature (2 m)']= seed_name_df['Average Temperature (2 m)'].str.replace(" ",'')

# %%
seed_name_df['Average Temperature (2 m)']= seed_name_df['Average Temperature (2 m)'].str.strip('°C')
seed_name_df['Average Temperature (2 m)']= seed_name_df['Average Temperature (2 m)'].str.replace('to','-')
seed_name_df['Average Temperature (2 m)']= seed_name_df['Average Temperature (2 m)'].astype(str).apply(empty_nan)

seed_name_df['Average Temperature (2 m)']= seed_name_df['Average Temperature (2 m)'].astype(str).apply(split_with_neg)

seed_name_df['Average Temperature (2 m)'].unique()
# Out:
# array([22.5, 18. , 22. , 20. , 25. , 25.6, 21. , 21.5, 24.5, 28.5, 15. ,
#        24. , 26. , 27.5, 23. , -5. , 17. , 25.5, 28. ,  nan, 30. , 16. ,
#        14.5, 19. , 17.5, 16.5, 20.5, 11.5, 10. , 12.5, 12. , 18.5,  0. ,
#        10.5,  7. , 14. , 15.5])

# %%
seed_name_df['Average Temperature (2 m)'] = seed_name_df['Average Temperature (2 m)'].fillna(seed_name_df['Average Temperature (2 m)'].mean())

# %%
seed_name_df['Average Temperature (2 m)']
# Out:
# 0       22.500000
# 1       18.000000
# 2       22.000000
# 3       22.000000
# 4       18.000000
# 5       20.000000
# 6       25.000000
# 7       20.000000
# 8       25.000000
# 9       25.600000
# 10      25.000000
# 11      25.000000
# 12      20.000000
# 13      20.000000
# 14      21.000000
# 15      18.000000
# 16      25.000000
# 17      25.000000
# 18      18.000000
# 19      20.000000
# 20      18.000000
# 21      25.000000
# 22      22.000000
# 23      25.000000
# 24      25.000000
# 25      25.000000
# 26      20.000000
# 27      20.000000
# 28      22.000000
# 29      25.000000
# 30      25.000000
# 31      25.000000
# 32      21.500000
# 33      25.000000
# 34      25.000000
# 35      25.000000
# 36      25.000000
# 37      25.000000
# 38      22.000000
# 39      25.000000
# 40      20.000000
# 41      20.000000
# 42      25.000000
# 43      25.000000
# 44      25.000000
# 45      25.000000
# 46      25.000000
# 47      25.000000
# 48      25.000000
# 49      24.500000
# ...

# %%
seed_name_df['Humidity(%)'].unique()
seed_name_df['Humidity(%)'] = seed_name_df['Humidity(%)'].str.strip("%")

# %%
seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].str.replace('to','-')
seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].str.replace(" ",'')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].str.replace('to','-')
#       2 seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].str.replace(" ",'')
#       3 seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].astype(str).apply(empty_nan)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].astype(str).apply(empty_nan)

seed_name_df['Humidity(%)']= seed_name_df['Humidity(%)'].astype(str).apply(split_with_neg)

# %%
seed_name_df['Humidity(%)'] = seed_name_df['Humidity(%)'].fillna(seed_name_df['Humidity(%)'].mean())

# %%
# seed_name_df['Humidity(%)'] = seed_name_df['Humidity(%)'].fillna(seed_name_df['Humidity(%)'].mean())

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Plant Category                                  1010 non-null   object
#  1   Seed Name                                       1010 non-null   object
#  2   Average Temperature (2 m)                       1010 non-null   object
#  3   Average Precipitation per day                   1010 non-null   object
#  4   Average Soil Temperature (0 to 6 cm)            1010 non-null   object
#  5   Average Soil Moisture (0-3 cm)                  1010 non-null   object
#  6   Average Evapotranspiration                      1010 non-null   object
#  7   Average Sunshine Duration                       1010 non-null   object
#  8   Humidity(%)                                     1010 non-null   object
# ...

# %%
cultivation = seed_name_df = df1[["Seed Name",'Watering (hours interval)','List of Fertilization','Time Period for Fertilization (weeks interval)','soil depth for sowing(inches)']]

# %%
cultivation['Watering (hours interval)']=cultivation['Watering (hours interval)'].str.strip("Every")
cultivation['Watering (hours interval)']=cultivation['Watering (hours interval)'].str.strip("Once every")
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3779394016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)']=cultivation['Watering (hours interval)'].str.strip("Every")
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3779394016.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)']=cultivation['Watering (hours interval)'].str.strip("Once every")

# %%
def converter(value):
    if 'hours' in value or 'weeks' in value or 'days' in values:
        min_val,max_val = [i for i in value.split(' ')]
        if max_val =='hours':
            return float(min_val)
        elif max_val =='days':
            return float(min_val/24)
        elif max_val =='weeks':
            return float(min_val/(24*7))

# %%
# seed_name_df['Watering (hours interval)'] = seed_name_df['Watering (hours interval)'].str.replace(" seconds",'_s')
cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].str.replace(" hours",'_h')
cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].str.replace(" days",'_d')
cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].str.replace(" weeks",'_w')



cultivation['Watering (hours interval)']
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3258331228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].str.replace(" hours",'_h')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3258331228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].str.replace(" days",'_d')
# ...

# %%
 cultivation[['Watering (hours interval)','unit']]=cultivation['Watering (hours interval)'].str.split('_',expand = True)
# cultivation[['Watering (hours interval','unit']]
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\4115031965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation[['Watering (hours interval)','unit']]=cultivation['Watering (hours interval)'].str.split('_',expand = True)

# %% [markdown]
# problems:
# 1) '-'
# 2) hours weeks days

# %%
# cultivation[['Watering (hours interval)','unit']]

# %%
cultivation['Watering (hours interval)'] =cultivation['Watering (hours interval)'].astype(str).apply(empty_nan)

cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].astype(str).apply(mean_val)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\916556847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)'] =cultivation['Watering (hours interval)'].astype(str).apply(empty_nan)
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\916556847.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Watering (hours interval)'] = cultivation['Watering (hours interval)'].astype(str).apply(mean_val)

# %%
for i in cultivation['Watering (hours interval)'].index:
    if cultivation.loc[i,'unit']== 'd':
        cultivation.loc[i,'Watering (hours interval)'] =cultivation.loc[i,'Watering (hours interval)']/24
    elif cultivation.loc[i,'unit']=='h':
        continue
    elif cultivation.loc[i,'unit']== 'w':
        cultivation.loc[i,'Watering (hours interval)'] =cultivation.loc[i,'Watering (hours interval)']/(24*7)
    # elif seed_name_df.loc[i,'unit']!= 'h' and seed_name_df.loc[i,'unit']!='d' andseed_name_df.loc[i,'unit']!='d'and seed_name_df.loc[i,'Watering (hours interval)']<=24:
    #     seed_name_df.loc[i,'Watering (hours interval)'] =seed_name_df.loc[i,'Watering (hours interval)']*360
    # elif seed_name_df.loc[i,'unit']!= 'h' and seed_name_df.loc[i,'unit']!='s' and seed_name_df.loc[i,'Watering (hours interval)']<=1800:
    #     seed_name_df.loc[i,'Watering (hours interval)'] =seed_name_df.loc[i,'Watering (hours interval)']*60
        # continue
    else:
        continue

# %%
cultivation['Time Period for Fertilization (weeks interval)'].unique()
# Out:
# array(['4', '8 weeks', '2', '8', '4 weeks', '2-4', '3', '4-6', '6',
#        'Every 4 weeks', '4 - 6', '2-3', ' ', '6-8', '4 to 6', '10', '0',
#        'Every 4-6 weeks', '12', '6 weeks'], dtype=object)

# %%
cultivation['Time Period for Fertilization (weeks interval)']=cultivation['Time Period for Fertilization (weeks interval)'].str.strip("Every")
cultivation['Time Period for Fertilization (weeks interval)']=cultivation['Time Period for Fertilization (weeks interval)'].str.strip("Once every")
cultivation['Time Period for Fertilization (weeks interval)'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\984554333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Time Period for Fertilization (weeks interval)']=cultivation['Time Period for Fertilization (weeks interval)'].str.strip("Every")
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\984554333.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
cultivation['Time Period for Fertilization (weeks interval)'] = cultivation['Time Period for Fertilization (weeks interval)'].astype(str).str.replace(" hours",'_h')
cultivation['Time Period for Fertilization (weeks interval)'] = cultivation['Time Period for Fertilization (weeks interval)'].astype(str).str.replace(" days",'_d')
cultivation['Time Period for Fertilization (weeks interval)'] = cultivation['Time Period for Fertilization (weeks interval)'].astype(str).str.replace(" weeks",'_w')




cultivation['Time Period for Fertilization (weeks interval)'].unique()
# cultivation['Time Period for Fertilization (weeks interval)'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3235611308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Time Period for Fertilization (weeks interval)'] = cultivation['Time Period for Fertilization (weeks interval)'].astype(str).str.replace(" hours",'_h')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3235611308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
cultivation[['Time Period for Fertilization (weeks interval)','unit']]= cultivation['Time Period for Fertilization (weeks interval)'].str.split('_',expand= True)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\3638090334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation[['Time Period for Fertilization (weeks interval)','unit']]= cultivation['Time Period for Fertilization (weeks interval)'].str.split('_',expand= True)

# %%
cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].str.replace('to','-')
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\498142922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].str.replace('to','-')

# %%
cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].astype(str).apply(empty_nan)

cultivation['Time Period for Fertilization (weeks interval)'] = cultivation['Time Period for Fertilization (weeks interval)'].astype(str).apply(mean_val)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\477322099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].astype(str).apply(empty_nan)
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\477322099.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].fillna(cultivation['Time Period for Fertilization (weeks interval)'].mean())
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\2129941005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['Time Period for Fertilization (weeks interval)'] =cultivation['Time Period for Fertilization (weeks interval)'].fillna(cultivation['Time Period for Fertilization (weeks interval)'].mean())

# %%
cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].str.strip('inches')
cultivation['soil depth for sowing(inches)'].unique()
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\96103199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].str.strip('inches')
# array(['1', '1 ', '0.5', '2', '0.5-1', '6', '1-2', '2 ', '0.5 ',
#        '0.25-0.5', '4', ' ', '0.2', '0.25', '2-4', '0.5-1.0', '1.5', '12',
#        '0', '0.4', '0.2 - 0.4'], dtype=object)

# %%
cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].str.replace(' ','')
cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].astype(str).apply(empty_nan)
cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].astype(str).apply(mean_val)
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\4276204485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].str.replace(' ','')
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\4276204485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].astype(str).apply(empty_nan)
# ...

# %%
cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].fillna(cultivation['soil depth for sowing(inches)'].mean())
# Out:
# C:\Users\LAPTOP HOUSE\AppData\Local\Temp\ipykernel_2152\4149449531.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cultivation['soil depth for sowing(inches)']=cultivation['soil depth for sowing(inches)'].fillna(cultivation['soil depth for sowing(inches)'].mean())

# %%
seed_name_df.to_csv('seed data.csv')
cultivation.to_csv('cultivation data.csv')
